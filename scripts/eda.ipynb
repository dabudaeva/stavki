# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Preprocessing & EDA

# %%
df = pd.read_csv('~/DS_bootcamp/stavki/data/ratings/international_matches.csv')
df['date'] = pd.to_datetime(df.date)
df.index = df['date']

# %%
df.loc[df.home_team.str.contains('China'), 'home_team'] = 'China'
df.loc[df.away_team.str.contains('China'), 'away_team'] = 'China'
df.loc[df.home_team.str.contains('Curaçao'), 'home_team'] = 'Curacao'
df.loc[df.away_team.str.contains('Curaçao'), 'away_team'] = 'Curacao'
df.loc[df.home_team.str.contains('Congo'), 'home_team'] = 'Congo'
df.loc[df.away_team.str.contains('Congo'), 'away_team'] = 'Congo'
df.loc[df.home_team.str.contains('German'), 'home_team'] = 'Germany'
df.loc[df.away_team.str.contains('German'), 'away_team'] = 'Germany'
df.loc[df.home_team.str.contains('Yemen'), 'home_team'] = 'Yemen'
df.loc[df.away_team.str.contains('Yemen'), 'away_team'] = 'Yemen'
df.loc[df.home_team.str.contains('Vietnam'), 'home_team'] = 'Vietnam'
df.loc[df.away_team.str.contains('Vietnam'), 'away_team'] = 'Vietnam'
df.loc[df.home_team.str.contains('Sint Maarten'), 'home_team'] = 'Saint Martin'
df.loc[df.away_team.str.contains('Sint Maarten'), 'away_team'] = 'Saint Martin'
df.loc[df.home_team.str.contains('São Tomé and Príncipe'), 'home_team'] = 'Sao Tome e Principe'
df.loc[df.away_team.str.contains('São Tomé and Príncipe'), 'away_team'] = 'Sao Tome e Principe'
df.home_team = df.home_team.replace('United States Virgin Islands', 'US Virgin Islands')
df.away_team = df.away_team.replace('United States Virgin Islands', 'US Virgin Islands')
df.home_team = df.home_team.replace('United States', 'USA')
df.away_team = df.away_team.replace('United States', 'USA')
df.loc[df.home_team.str.contains('Brunei'), 'home_team'] = 'Brunei'
df.loc[df.away_team.str.contains('Brunei'), 'away_team'] = 'Brunei'
df.loc[df.home_team.str.contains('Cabo'), 'home_team'] = 'Cape Verde'
df.loc[df.away_team.str.contains('Cabo'), 'away_team'] = 'Cape Verde'
df.loc[df.home_team.str.contains('Cape'), 'home_team'] = 'Cape Verde'
df.loc[df.away_team.str.contains('Cape'), 'away_team'] = 'Cape Verde'
df.loc[df.home_team.str.contains('Curaçao'), 'home_team'] = 'Curacao'
df.loc[df.away_team.str.contains('Curaçao'), 'away_team'] = 'Curacao'
df.loc[df.home_team.str.contains('Iran'), 'home_team'] = 'Iran'
df.loc[df.away_team.str.contains('Iran'), 'away_team'] = 'Iran'
df.loc[df.home_team.str.contains('Chinese Taipei'), 'home_team'] = 'China'
df.loc[df.away_team.str.contains('Chinese Taipei'), 'away_team'] = 'China'
df.loc[df.home_team.str.contains('China PR'), 'home_team'] = 'China'
df.loc[df.away_team.str.contains('China PR'), 'away_team'] = 'China'
df.loc[df.home_team.str.contains('Congo DR'), 'home_team'] = 'Congo'
df.loc[df.away_team.str.contains('Congo DR'), 'away_team'] = 'Congo'
df.loc[df.home_team.str.contains('Türkiye'), 'home_team'] = 'Turkey'
df.loc[df.away_team.str.contains('Türkiye'), 'away_team'] = 'Turkey'
df.loc[df.home_team.str.contains('Tomé'), 'home_team'] = 'Sao Tome e Principe'
df.loc[df.away_team.str.contains('Tomé'), 'away_team'] = 'Sao Tome e Principe'
df.loc[df.home_team.str.contains('Korea Republic'), 'home_team'] = 'South Korea'
df.loc[df.away_team.str.contains('Korea Republic'), 'away_team'] = 'South Korea'
df.loc[df.home_team.str.contains('Korea DPR'), 'home_team'] = 'North Korea'
df.loc[df.away_team.str.contains('Korea DPR'), 'away_team'] = 'North Korea'
df.loc[df.home_team.str.contains('Kyrgyz Republic'), 'home_team'] = 'Kyrgyzstan'
df.loc[df.away_team.str.contains('Kyrgyz Republic'), 'away_team'] = 'Kyrgyzstan'
df.loc[df.home_team.str.contains('Netherlands'), 'home_team'] = 'Netherlands'
df.loc[df.away_team.str.contains('Netherlands'), 'away_team'] = 'Netherlands'
df.loc[df.home_team.str.contains('Macedonia'), 'home_team'] = 'North Macedonia'
df.loc[df.away_team.str.contains('Macedonia'), 'away_team'] = 'North Macedonia'
df.loc[df.home_team.str.contains('Zaire'), 'home_team'] = 'Congo'
df.loc[df.away_team.str.contains('Zaire'), 'away_team'] = 'Congo'
df.loc[df.home_team.str.contains('Vincent / Grenadines'), 'home_team'] = 'Saint Vincent and the Grenadines'
df.loc[df.away_team.str.contains('Vincent / Grenadines'), 'away_team'] = 'Saint Vincent and the Grenadines'
df['home_team'] = df['home_team'].str.replace('St.', 'Saint', regex=True)
df['away_team'] = df['away_team'].str.replace('St.', 'Saint', regex=True)

# %%
# home_continent = pd.get_dummies(df.home_team_continent, prefix='home_')
# away_continent = pd.get_dummies(df.away_team_continent, prefix='away_')
# df = pd.concat([df, home_continent, away_continent], axis=1)

# df['dif_rank'] = df.home_team_fifa_rank-df.away_team_fifa_rank
# df['dif_points'] = df.home_team_total_fifa_points-df.away_team_total_fifa_points
# df['dif_goalkeeper'] = df.home_team_goalkeeper_score-df.away_team_goalkeeper_score
# df['dif_defense'] = df.home_team_mean_defense_score-df.away_team_mean_defense_score
# df['dif_offense'] = df.home_team_mean_offense_score-df.away_team_mean_offense_score
# df['dif_midfield'] = df.home_team_mean_midfield_score-df.away_team_mean_midfield_score

# df['ave_rank'] = (df.home_team_fifa_rank+df.away_team_fifa_rank)/2
# df['ave_points'] = (df.home_team_total_fifa_points+df.away_team_total_fifa_points)/2
# df['ave_goalkeeper'] = (df.home_team_goalkeeper_score+df.away_team_goalkeeper_score)/2
# df['ave_defense'] = (df.home_team_mean_defense_score+df.away_team_mean_defense_score)/2
# df['ave_offense'] = (df.home_team_mean_offense_score+df.away_team_mean_offense_score)/2
# df['ave_midfield'] = (df.home_team_mean_midfield_score+df.away_team_mean_midfield_score)/2

# df['home_result'] = df.home_team_result
# df['neutral_location'] = df.neutral_location.map({False:0, True:1})
# df['shoot_out'] = df.shoot_out.map({'No':0, 'Yes':1})
# df['date']=df.date.dt.year
# df = df.fillna(0)

# df = df.drop(['home_team_result', 'home_team_score', 'away_team_score',
#               'home_team_continent', 'away_team_continent',
#               'home_team', 'away_team', 'tournament', 'city', 'country'], axis=1)
# df = df.dropna()
# df.info()

# %%
teams = [['Qatar', 'Ecuador', 'Senegal', 'Netherlands'], 
         ['England', 'Iran', 'USA', 'Wales'], 
         ['Argentina', 'Saudi Arabia', 'Mexico', 'Poland'], 
         ['France', 'Australia', 'Denmark', 'Tunisia'], 
         ['Spain', 'Costa Rica', 'Germany', 'Japan'], 
         ['Belgium', 'Canada', 'Morocco', 'Croatia'],
         ['Brazil', 'Serbia', 'Switzerland', 'Cameroon'], 
         ['Portugal', 'Ghana', 'Uruguay', 'South Korea']]

# %%
cols_home = ['date', 'home_team', 'home_team_continent', 'home_team_fifa_rank', 'home_team_total_fifa_points',
             'home_team_score', 'tournament', 'city', 'country', 'neutral_location', 'shoot_out', 'home_team_result',
             'home_team_goalkeeper_score', 'home_team_mean_defense_score', 'home_team_mean_offense_score',
             'home_team_mean_midfield_score']
cols_away = ['date', 'away_team', 'away_team_continent', 'away_team_fifa_rank', 'away_team_total_fifa_points',
             'away_team_score', 'tournament', 'city', 'country', 'neutral_location', 'shoot_out', 'home_team_result',
             'away_team_goalkeeper_score', 'away_team_mean_defense_score', 'away_team_mean_offense_score', 
             'away_team_mean_midfield_score']
home = df[cols_home].loc[df['home_team'].isin(sum(teams, []))]
away = df[cols_away].loc[df['away_team'].isin(sum(teams, []))]
away['home_team_result'] = away.home_team_result.map({'Win':'Lose', 'Draw':'Draw', 'Lose':'Win'})
home.columns = ['date', 'team', 'continent', 'rank', 'points', 'score', 'tournament', 'city', 'country', 'neutral_location', 
                'shoot_out', 'result','goalkeeper', 'defense', 'offense','midfield']
away.columns = ['date', 'team', 'continent', 'rank', 'points', 'score', 'tournament', 'city', 'country', 'neutral_location', 
                'shoot_out', 'result','goalkeeper', 'defense', 'offense','midfield']
team_data = pd.concat([home, away])

# %%
team_data.head()
# Out:
#                  date       team      continent  rank  points  score  \
# date
# 1993-08-08 1993-08-08     Brazil  South America     8       0      1
# 1993-08-08 1993-08-08    Ecuador  South America    35       0      5
# 1993-08-15 1993-08-15  Australia        Oceania    52       0      2
# 1993-08-15 1993-08-15    Uruguay  South America    22       0      1
# 1993-08-22 1993-08-22  Argentina  South America     5       0      2
#
#                               tournament          city    country  \
# date
# 1993-08-08                      Friendly        Maceió     Brazil
# 1993-08-08  FIFA World Cup qualification         Quito    Ecuador
# 1993-08-15  FIFA World Cup qualification        Sydney  Australia
# 1993-08-15  FIFA World Cup qualification    Montevideo    Uruguay
# 1993-08-22  FIFA World Cup qualification  Buenos Aires  Argentina
#
#             neutral_location shoot_out result  goalkeeper  defense  offense  \
# date
# ...

# %% [markdown]
# # Points

# %%
points = team_data[['date', 'team', 'points']].drop_duplicates()
points = points.groupby([pd.Grouper(freq='Y'), 'team'])
points = points['points'].mean().unstack('team')

fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2,4, figsize=(13,6))

points[points.columns[points.columns.isin(teams[0])]].plot(ax=ax1).set(title='Group A', xlabel='', ylabel='')
points[points.columns[points.columns.isin(teams[1])]].plot(ax=ax2).set(title='Group B', xlabel='', ylabel='')
points[points.columns[points.columns.isin(teams[2])]].plot(ax=ax3).set(title='Group C', xlabel='', ylabel='')
points[points.columns[points.columns.isin(teams[3])]].plot(ax=ax4).set(title='Group D', xlabel='', ylabel='')
points[points.columns[points.columns.isin(teams[4])]].plot(ax=ax5).set(title='Group E', xlabel='', ylabel='')
points[points.columns[points.columns.isin(teams[5])]].plot(ax=ax6).set(title='Group F', xlabel='', ylabel='')
points[points.columns[points.columns.isin(teams[6])]].plot(ax=ax7).set(title='Group G', xlabel='', ylabel='')
points[points.columns[points.columns.isin(teams[7])]].plot(ax=ax8).set(title='Group H', xlabel='', ylabel='')

ax1.legend(points.columns[points.columns.isin(teams[0])])
ax2.legend(points.columns[points.columns.isin(teams[1])])
ax3.legend(points.columns[points.columns.isin(teams[2])])
ax4.legend(points.columns[points.columns.isin(teams[3])])
ax5.legend(points.columns[points.columns.isin(teams[4])])
ax6.legend(points.columns[points.columns.isin(teams[5])])
ax7.legend(points.columns[points.columns.isin(teams[6])])
ax8.legend(points.columns[points.columns.isin(teams[7])])

plt.show()

# %%
rank = team_data[['date', 'team', 'rank']].drop_duplicates()
rank = rank.groupby([pd.Grouper(freq='Y'), 'team'])
rank = rank['rank'].mean().unstack('team')

fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2,4, figsize=(13,6))

rank[points.columns[rank.columns.isin(teams[0])]].plot(ax=ax1).set(title='Group A', xlabel='', ylabel='')
rank[points.columns[rank.columns.isin(teams[1])]].plot(ax=ax2).set(title='Group B', xlabel='', ylabel='')
rank[points.columns[rank.columns.isin(teams[2])]].plot(ax=ax3).set(title='Group C', xlabel='', ylabel='')
rank[points.columns[rank.columns.isin(teams[3])]].plot(ax=ax4).set(title='Group D', xlabel='', ylabel='')
rank[points.columns[rank.columns.isin(teams[4])]].plot(ax=ax5).set(title='Group E', xlabel='', ylabel='')
rank[points.columns[rank.columns.isin(teams[5])]].plot(ax=ax6).set(title='Group F', xlabel='', ylabel='')
rank[points.columns[rank.columns.isin(teams[6])]].plot(ax=ax7).set(title='Group G', xlabel='', ylabel='')
rank[points.columns[rank.columns.isin(teams[7])]].plot(ax=ax8).set(title='Group H', xlabel='', ylabel='')

ax1.legend(rank.columns[rank.columns.isin(teams[0])])
ax2.legend(rank.columns[rank.columns.isin(teams[1])])
ax3.legend(rank.columns[rank.columns.isin(teams[2])])
ax4.legend(rank.columns[rank.columns.isin(teams[3])])
ax5.legend(rank.columns[rank.columns.isin(teams[4])])
ax6.legend(rank.columns[rank.columns.isin(teams[5])])
ax7.legend(rank.columns[rank.columns.isin(teams[6])])
ax8.legend(rank.columns[rank.columns.isin(teams[7])])

plt.show()

# %%
goalkeeper = team_data[['date', 'team', 'goalkeeper']].drop_duplicates().dropna()
goalkeeper = goalkeeper.groupby([pd.Grouper(freq='Y'), 'team'])
goalkeeper = goalkeeper['goalkeeper'].mean().unstack('team')

fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2,4, figsize=(13,6))

goalkeeper[goalkeeper.columns[goalkeeper.columns.isin(teams[0])]].plot(ax=ax1).set(title='Group A', xlabel='', ylabel='')
goalkeeper[goalkeeper.columns[goalkeeper.columns.isin(teams[1])]].plot(ax=ax2).set(title='Group B', xlabel='', ylabel='')
goalkeeper[goalkeeper.columns[goalkeeper.columns.isin(teams[2])]].plot(ax=ax3).set(title='Group C', xlabel='', ylabel='')
goalkeeper[goalkeeper.columns[goalkeeper.columns.isin(teams[3])]].plot(ax=ax4).set(title='Group D', xlabel='', ylabel='')
goalkeeper[goalkeeper.columns[goalkeeper.columns.isin(teams[4])]].plot(ax=ax5).set(title='Group E', xlabel='', ylabel='')
goalkeeper[goalkeeper.columns[goalkeeper.columns.isin(teams[5])]].plot(ax=ax6).set(title='Group F', xlabel='', ylabel='')
goalkeeper[goalkeeper.columns[goalkeeper.columns.isin(teams[6])]].plot(ax=ax7).set(title='Group G', xlabel='', ylabel='')
goalkeeper[goalkeeper.columns[goalkeeper.columns.isin(teams[7])]].plot(ax=ax8).set(title='Group H', xlabel='', ylabel='')

ax1.legend(goalkeeper.columns[goalkeeper.columns.isin(teams[0])])
ax2.legend(goalkeeper.columns[goalkeeper.columns.isin(teams[1])])
ax3.legend(goalkeeper.columns[goalkeeper.columns.isin(teams[2])])
ax4.legend(goalkeeper.columns[goalkeeper.columns.isin(teams[3])])
ax5.legend(goalkeeper.columns[goalkeeper.columns.isin(teams[4])])
ax6.legend(goalkeeper.columns[goalkeeper.columns.isin(teams[5])])
ax7.legend(goalkeeper.columns[goalkeeper.columns.isin(teams[6])])
ax8.legend(goalkeeper.columns[goalkeeper.columns.isin(teams[7])])

plt.show()

# %%
defense = team_data[['date', 'team', 'defense']].drop_duplicates().dropna()
defense = defense.groupby([pd.Grouper(freq='Y'), 'team'])
defense = defense['defense'].mean().unstack('team')

fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2,4, figsize=(13,6))

defense[defense.columns[defense.columns.isin(teams[0])]].plot(ax=ax1).set(title='Group A', xlabel='', ylabel='')
defense[defense.columns[defense.columns.isin(teams[1])]].plot(ax=ax2).set(title='Group B', xlabel='', ylabel='')
defense[defense.columns[defense.columns.isin(teams[2])]].plot(ax=ax3).set(title='Group C', xlabel='', ylabel='')
defense[defense.columns[defense.columns.isin(teams[3])]].plot(ax=ax4).set(title='Group D', xlabel='', ylabel='')
defense[defense.columns[defense.columns.isin(teams[4])]].plot(ax=ax5).set(title='Group E', xlabel='', ylabel='')
defense[defense.columns[defense.columns.isin(teams[5])]].plot(ax=ax6).set(title='Group F', xlabel='', ylabel='')
defense[defense.columns[defense.columns.isin(teams[6])]].plot(ax=ax7).set(title='Group G', xlabel='', ylabel='')
defense[defense.columns[defense.columns.isin(teams[7])]].plot(ax=ax8).set(title='Group H', xlabel='', ylabel='')

ax1.legend(defense.columns[defense.columns.isin(teams[0])])
ax2.legend(defense.columns[defense.columns.isin(teams[1])])
ax3.legend(defense.columns[defense.columns.isin(teams[2])])
ax4.legend(defense.columns[defense.columns.isin(teams[3])])
ax5.legend(defense.columns[defense.columns.isin(teams[4])])
ax6.legend(defense.columns[defense.columns.isin(teams[5])])
ax7.legend(defense.columns[defense.columns.isin(teams[6])])
ax8.legend(defense.columns[defense.columns.isin(teams[7])])

plt.show()

# %%
offense = team_data[['date', 'team', 'offense']].drop_duplicates().dropna()
offense = offense.groupby([pd.Grouper(freq='Y'), 'team'])
offense = offense['offense'].mean().unstack('team')

fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2,4, figsize=(13,6))

offense[offense.columns[offense.columns.isin(teams[0])]].plot(ax=ax1).set(title='Group A', xlabel='', ylabel='')
offense[offense.columns[offense.columns.isin(teams[1])]].plot(ax=ax2).set(title='Group B', xlabel='', ylabel='')
offense[offense.columns[offense.columns.isin(teams[2])]].plot(ax=ax3).set(title='Group C', xlabel='', ylabel='')
offense[offense.columns[offense.columns.isin(teams[3])]].plot(ax=ax4).set(title='Group D', xlabel='', ylabel='')
offense[offense.columns[offense.columns.isin(teams[4])]].plot(ax=ax5).set(title='Group E', xlabel='', ylabel='')
offense[offense.columns[offense.columns.isin(teams[5])]].plot(ax=ax6).set(title='Group F', xlabel='', ylabel='')
offense[offense.columns[offense.columns.isin(teams[6])]].plot(ax=ax7).set(title='Group G', xlabel='', ylabel='')
offense[offense.columns[offense.columns.isin(teams[7])]].plot(ax=ax8).set(title='Group H', xlabel='', ylabel='')

ax1.legend(offense.columns[offense.columns.isin(teams[0])])
ax2.legend(offense.columns[offense.columns.isin(teams[1])])
ax3.legend(offense.columns[offense.columns.isin(teams[2])])
ax4.legend(offense.columns[offense.columns.isin(teams[3])])
ax5.legend(offense.columns[offense.columns.isin(teams[4])])
ax6.legend(offense.columns[offense.columns.isin(teams[5])])
ax7.legend(offense.columns[offense.columns.isin(teams[6])])
ax8.legend(offense.columns[offense.columns.isin(teams[7])])

plt.show()

# %%
midfield = team_data[['date', 'team', 'midfield']].drop_duplicates().dropna()
midfield = midfield.groupby([pd.Grouper(freq='Y'), 'team'])
midfield = midfield['midfield'].mean().unstack('team')

fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2,4, figsize=(13,6))

midfield[offense.columns[midfield.columns.isin(teams[0])]].plot(ax=ax1).set(title='Group A', xlabel='', ylabel='')
midfield[offense.columns[midfield.columns.isin(teams[1])]].plot(ax=ax2).set(title='Group B', xlabel='', ylabel='')
midfield[offense.columns[midfield.columns.isin(teams[2])]].plot(ax=ax3).set(title='Group C', xlabel='', ylabel='')
midfield[offense.columns[midfield.columns.isin(teams[3])]].plot(ax=ax4).set(title='Group D', xlabel='', ylabel='')
midfield[offense.columns[midfield.columns.isin(teams[4])]].plot(ax=ax5).set(title='Group E', xlabel='', ylabel='')
midfield[offense.columns[midfield.columns.isin(teams[5])]].plot(ax=ax6).set(title='Group F', xlabel='', ylabel='')
midfield[offense.columns[midfield.columns.isin(teams[6])]].plot(ax=ax7).set(title='Group G', xlabel='', ylabel='')
midfield[offense.columns[midfield.columns.isin(teams[7])]].plot(ax=ax8).set(title='Group H', xlabel='', ylabel='')

ax1.legend(midfield.columns[midfield.columns.isin(teams[0])])
ax2.legend(midfield.columns[midfield.columns.isin(teams[1])])
ax3.legend(midfield.columns[midfield.columns.isin(teams[2])])
ax4.legend(midfield.columns[midfield.columns.isin(teams[3])])
ax5.legend(midfield.columns[midfield.columns.isin(teams[4])])
ax6.legend(midfield.columns[midfield.columns.isin(teams[5])])
ax7.legend(midfield.columns[midfield.columns.isin(teams[6])])
ax8.legend(midfield.columns[midfield.columns.isin(teams[7])])

plt.show()

# %%
network_data.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_team_continent',
#        'away_team_continent', 'home_team_fifa_rank', 'away_team_fifa_rank',
#        'home_team_total_fifa_points', 'away_team_total_fifa_points',
#        'home_team_score', 'away_team_score', 'tournament', 'city', 'country',
#        'neutral_location', 'shoot_out', 'home_team_result',
#        'home_team_goalkeeper_score', 'away_team_goalkeeper_score',
#        'home_team_mean_defense_score', 'home_team_mean_offense_score',
#        'home_team_mean_midfield_score', 'away_team_mean_defense_score',
#        'away_team_mean_offense_score', 'away_team_mean_midfield_score'],
#       dtype='object')

# %%
home = df.loc[df['home_team'].isin(sum(teams, []))]
away = df.loc[df['away_team'].isin(sum(teams, []))]
network_data = pd.concat([home, away])

# %%
network_rank = network_data.groupby(['home_team', 'away_team']).agg({'home_team_fifa_rank':'mean', 
                                                                     'away_team_fifa_rank':'mean'}).reset_index()
network_rank['difference'] = abs(network_rank.home_team_fifa_rank-network_rank.away_team_fifa_rank)

# %%
network_rank
# Out:
#         home_team away_team  home_team_fifa_rank  away_team_fifa_rank  \
# 0     Afghanistan     Japan               130.00                 58.0
# 1     Afghanistan     Qatar               149.00                 57.0
# 2         Albania  Cameroon                67.00                 62.0
# 3         Albania   Denmark                79.75                 17.0
# 4         Albania   England                70.50                 10.0
# ...           ...       ...                  ...                  ...
# 3386     Zimbabwe  Cameroon                56.50                 38.5
# 3387     Zimbabwe     Ghana                77.50                 42.0
# 3388     Zimbabwe   Morocco                99.00                 58.5
# 3389     Zimbabwe   Senegal                51.50                 44.0
# 3390     Zimbabwe   Tunisia               103.00                 36.0
#
#       difference
# 0          72.00
# 1          92.00
# 2           5.00
# 3          62.75
# 4          60.50
# ...

# %%
import pandas as pd
import networkx as nx
from pyvis.network import Network

# %%
G = nx.from_pandas_edgelist(network_rank, source='home_team', target='away_team')

# %%
net = Network(notebook=True, directed=False)
net.from_nx(G)
# Out:
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.

# %%
# net.show('example.html')
